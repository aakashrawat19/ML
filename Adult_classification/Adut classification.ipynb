# %%
import pandas as pd  ####### for dat manipulation like reading csv, converting categorical data into numerical

# %%
from sklearn.model_selection import train_test_split   ###### dividing dataset in training and testing data

# %%
from sklearn.metrics import accuracy_score          ######## to know the accuracy of the model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.linear_model import LogisticRegression

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
##############   reading data from csv file to a dataframe 
adult = pd.read_csv('adult.csv',sep= ',',names = ["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"])

# %%
adult.shape     ############# shape of the data
# Out:
# (162805, 15)

# %%
adult.head()    ###########  print 1st five samples of dataset
# Out:
#    Age          Workclass  fnlwgt   Education  Education-Num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         Martial Status          Occupation    Relationship    Race      Sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    Capital Gain  Capital Loss  Hours per week         Country  Target
# 0          2174             0              40   United-States   <=50K
# ...

# %%
adult.tail()    ############# print last five samples of the dataset
# Out:
#         Age      Workclass  fnlwgt    Education  Education-Num  \
# 162800   27        Private  257302   Assoc-acdm             12
# 162801   40        Private  154374      HS-grad              9
# 162802   58        Private  151910      HS-grad              9
# 162803   22        Private  201490      HS-grad              9
# 162804   52   Self-emp-inc  287927      HS-grad              9
#
#              Martial Status          Occupation Relationship    Race      Sex  \
# 162800   Married-civ-spouse        Tech-support         Wife   White   Female
# 162801   Married-civ-spouse   Machine-op-inspct      Husband   White     Male
# 162802              Widowed        Adm-clerical    Unmarried   White   Female
# 162803        Never-married        Adm-clerical    Own-child   White     Male
# 162804   Married-civ-spouse     Exec-managerial         Wife   White   Female
#
#         Capital Gain  Capital Loss  Hours per week         Country  Target
# ...

# %%
adult.describe()    ############ describing dataset
# Out:
#                  Age        fnlwgt  Education-Num   Capital Gain  \
# count  162805.000000  1.628050e+05  162805.000000  162805.000000
# mean       38.581647  1.897784e+05      10.080679    1077.648844
# std        13.640265  1.055487e+05       2.572689    7385.201358
# min        17.000000  1.228500e+04       1.000000       0.000000
# 25%        28.000000  1.178270e+05       9.000000       0.000000
# 50%        37.000000  1.783560e+05      10.000000       0.000000
# 75%        48.000000  2.370510e+05      12.000000       0.000000
# max        90.000000  1.484705e+06      16.000000   99999.000000
#
#         Capital Loss  Hours per week
# count  162805.000000   162805.000000
# mean       87.303830       40.437456
# std       402.955268       12.347277
# min         0.000000        1.000000
# 25%         0.000000       40.000000
# 50%         0.000000       40.000000
# 75%         0.000000       45.000000
# max      4356.000000       99.000000

# %%
adult.isnull().sum()
# Out:
# Age               0
# Workclass         0
# fnlwgt            0
# Education         0
# Education-Num     0
# Martial Status    0
# Occupation        0
# Relationship      0
# Race              0
# Sex               0
# Capital Gain      0
# Capital Loss      0
# Hours per week    0
# Country           0
# Target            0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder    ######### used for converting categorical values into numerical values

# %%
le = LabelEncoder()

# %%
for col in adult.columns:
    if adult[col].dtypes =='object':            ####### when column's data type is equal to object
        adult[col] = le.fit_transform(adult[col])     ###### fit_transform is used for conversion

# %%
adult.head()
# Out:
#    Age  Workclass  fnlwgt  Education  Education-Num  Martial Status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    Occupation  Relationship  Race  Sex  Capital Gain  Capital Loss  \
# 0           1             1     4    1          2174             0
# 1           4             0     4    1             0             0
# 2           6             1     4    1             0             0
# 3           6             0     2    1             0             0
# 4          10             5     2    0             0             0
#
#    Hours per week  Country  Target
# 0              40       39       0
# 1              13       39       0
# 2              40       39       0
# ...

# %%
#################  seperating target and input features
X = adult[["Age", "Workclass", "fnlwgt", "Education", "Education-Num", "Martial Status",
        "Occupation", "Relationship", "Race", "Sex", "Capital Gain", "Capital Loss",
        "Hours per week", "Country", "Target"]]

# %%
Y = adult.Target

# %%
x_train,x_test,y_train,y_test = train_test_split(X,Y,test_size =0.30,random_state = 42)  ######  dividing dataset

# %%
model = []     ########### list for containing  tuples and tuples contains name of the algorithm and algorithm instance

# %%
model.append(("LR",LogisticRegression()))
model.append(("LDA",LinearDiscriminantAnalysis()))
model.append(("KNN",KNeighborsClassifier()))
model.append(("CART",DecisionTreeClassifier()))
model.append(("NB",GaussianNB()))

# %%
result = []    ##### empty list , used for storing result

# %%
names = []     ##### empty list for storing the names of the algorithm

# %%
from sklearn import model_selection  #### used for kfold and cross_val_score functions

# %%
for name,models  in model:
    kfold = model_selection.KFold(n_splits =10 ,random_state =7)
    cv_result = model_selection.cross_val_score(models,x_train,y_train,cv=kfold,scoring="accuracy")
    result.append(cv_result)
    names.append(name)
    msg = "%s,%f(%f)"%(name,cv_result.mean(),cv_result.std())
    print(msg)
# Out:
# LR,0.796539(0.005755)
# /home/luffy/anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /home/luffy/anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /home/luffy/anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /home/luffy/anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# /home/luffy/anaconda3/lib/python3.6/site-packages/sklearn/discriminant_analysis.py:388: UserWarning: Variables are collinear.
#   warnings.warn("Variables are collinear.")
# ...
